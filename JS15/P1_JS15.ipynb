# %% [markdown]
# # 🌊Praktikum 1
# Klasifikasi Gambar (Day vs Night) dengan Neural Network.
#
# ## Membangun & Ekspor Model
# Pada praktikum bagian pertama ini, kita akan melatih model dan menyimpan "artefak" (file hasil training) yang dibutuhkan untuk deployment. Dengan melakukan Klasifikasi Gambar (Day vs Night) mengunakan Neural Network.

# %% [markdown]
# ## Langkah 1: Import Library dan Mount Google Drive
# Langkah pertama adalah mengimpor pustaka yang diperlukan untuk pengolahan citra, machine learning, dan deep learning, serta menghubungkan Google Colab dengan Google Drive.

# %%
from pathlib import Path
import numpy as np
import matplotlib.pyplot as plt
import cv2

from skimage.feature import hog
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, models

# %% [markdown]
# ## Langkah 2: Load Dataset
# Membaca gambar dari direktori training dan testing, lalu menyimpannya dalam list bersama dengan labelnya.

# %%
# Load images and labels from a directory structure
def load_dataset(img_dir):
    p = Path(img_dir)
    img_list = []
    
    # Check if directory exists
    if not p.exists():
        print(f"⚠️ Warning: Directory '{img_dir}' does not exist!")
        return img_list
    
    for folder in p.glob('*'):
        if not folder.is_dir():
            continue
        label = folder.name
        image_count = 0
        for file in folder.glob('*.jpg'):
            img = cv2.imread(str(file))
            if img is None:
                print(f"⚠️ Warning: Could not read {file}")
                continue
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img_list.append((img, label))
            image_count += 1
        print(f"  Loaded {image_count} images from '{label}' folder")
    
    return img_list

# Fix directory paths - use relative path from JS15 folder
train_dir = "images/training"
test_dir  = "images/test"

print("Loading training images...")
train_img = load_dataset(train_dir)
print("\nLoading test images...")
test_img  = load_dataset(test_dir)

print(f"\n✅ Jumlah data training: {len(train_img)}")
print(f"✅ Jumlah data testing: {len(test_img)}")

# Validate that we have data
if len(train_img) == 0:
    raise ValueError("❌ No training images loaded! Please check your directory path.")
if len(test_img) == 0:
    raise ValueError("❌ No test images loaded! Please check your directory path.")
# Out:
# Loading training images...
#   Loaded 120 images from 'day' folder
#   Loaded 120 images from 'day' folder
#   Loaded 120 images from 'night' folder
#
# Loading test images...
#   Loaded 120 images from 'night' folder
#
# Loading test images...
#   Loaded 80 images from 'day' folder
#   Loaded 80 images from 'day' folder
#   Loaded 80 images from 'night' folder
#
# ✅ Jumlah data training: 240
# ✅ Jumlah data testing: 160
#   Loaded 80 images from 'night' folder
#
# ✅ Jumlah data training: 240
# ✅ Jumlah data testing: 160

# %% [markdown]
# ## Langkah 3: Preprocessing (Resize & Label Encoding)
# Mengubah ukuran gambar menjadi 256x256 piksel dan mengubah label teks ('day'/'night') menjadi angka biner (1/0).

# %%
# Preprocess images: resize and encode labels
def resize_image(img, size=(256,256)):
    return cv2.resize(img, size)

def label_encoder(label):
    return 1 if label == 'day' else 0

def preprocess(img_list):
    X = []
    y = []
    for img, label in img_list:
        img_std = resize_image(img)
        X.append(img_std)
        y.append(label_encoder(label))
    return X, y

X_train_img, y_train = preprocess(train_img)
X_test_img,  y_test  = preprocess(test_img)

# %% [markdown]
# ## Langkah 4: Ekstraksi Fitur HOG (Histogram of Oriented Gradients)
# Mengekstraksi fitur bentuk dan tekstur dari gambar menggunakan metode HOG.

# %%
# Extract HOG features
def extract_hog(X_imgs):
    if len(X_imgs) == 0:
        raise ValueError("❌ No images to extract features from!")
    
    feats = []
    for img in X_imgs:
        gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)
        hog_feat = hog(gray,
                       orientations=9,
                       pixels_per_cell=(8,8),
                       cells_per_block=(2,2),
                       block_norm='L2-Hys',
                       visualize=False,
                       feature_vector=True)
        feats.append(hog_feat)
    return np.array(feats)

X_train_feat = extract_hog(X_train_img)
X_test_feat  = extract_hog(X_test_img)

print(f"✅ X_train_feat shape: {X_train_feat.shape}")
print(f"✅ X_test_feat shape: {X_test_feat.shape}")
# Out:
# ✅ X_train_feat shape: (240, 34596)
# ✅ X_test_feat shape: (160, 34596)

# %% [markdown]
# ## Langkah 5: Normalisasi Fitur
# Menstandarisasi fitur agar memiliki rata-rata 0 dan variansi 1 menggunakan StandardScaler.

# %%
# Normalize features
scaler = StandardScaler()

# Validate feature array is not empty
if X_train_feat.size == 0:
    raise ValueError("❌ X_train_feat is empty! Cannot fit scaler.")

X_train_scaled = scaler.fit_transform(X_train_feat)
X_test_scaled  = scaler.transform(X_test_feat)

print(f"✅ X_train_scaled shape: {X_train_scaled.shape}")
print(f"✅ X_test_scaled shape: {X_test_scaled.shape}")
# Out:
# ✅ X_train_scaled shape: (240, 34596)
# ✅ X_test_scaled shape: (160, 34596)

# %% [markdown]
# ## Langkah 6: Split Data Training & Validation
# Memisahkan data training menjadi data train dan validation.

# %%
# Split training data for validation
X_train, X_val, y_train, y_val = train_test_split(
    X_train_scaled, y_train,
    test_size=0.2,
    random_state=42
)

# %% [markdown]
# ## Langkah 7: Konversi Label ke Numpy Array
# Mengubah list label menjadi format numpy array agar kompatibel dengan TensorFlow/Keras.

# %%
# Convert labels to numpy arrays (required for Keras)
y_train = np.array(y_train)
y_val = np.array(y_val)
y_test = np.array(y_test)

# %% [markdown]
# ## Langkah 8: Membangun Arsitektur Model Neural Network
# Membuat model Sequential dengan 3 layer (Input, Hidden Layers dengan ReLU, dan Output Layer dengan Sigmoid).

# %%
# Build a simple feedforward neural network
# Define model architecture
# input_dim is the number of features in the dataset
# Hidden layer -> 128 neurons, ReLU activation
# Hidden layer -> 64 neurons, ReLU activation
# Output layer -> 1 neuron, Sigmoid activation (for binary classification)
input_dim = X_train.shape[1]

model = models.Sequential([
    layers.Input(shape=(input_dim,)),
    layers.Dense(128, activation='relu'),
    layers.Dense(64, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │     4,428,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,436,737 (16.92 MB)
#  Trainable params: 4,436,737 (16.92 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ## Langkah 9: Training Model
# Melatih model menggunakan data training selama 20 epoch.

# %%
# Train the model
history = model.fit(
    X_train, y_train,
    epochs=20,
    batch_size=32,
    validation_data=(X_val, y_val)
)
# Out:
# Epoch 1/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7969 - loss: 0.9483 - val_accuracy: 0.9583 - val_loss: 0.3230
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 61ms/step - accuracy: 0.7969 - loss: 0.9483 - val_accuracy: 0.9583 - val_loss: 0.3230
# Epoch 2/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0967 - val_accuracy: 0.9583 - val_loss: 0.6531
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0967 - val_accuracy: 0.9583 - val_loss: 0.6531
# Epoch 3/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0231 - val_accuracy: 0.9792 - val_loss: 0.4666
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9896 - loss: 0.0231 - val_accuracy: 0.9792 - val_loss: 0.4666
# Epoch 4/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9948 - loss: 0.0076 - val_accuracy: 0.9792 - val_loss: 0.4942
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9948 - loss: 0.0076 - val_accuracy: 0.9792 - val_loss: 0.4942
# Epoch 5/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 4.1353e-05 - val_accuracy: 0.9792 - val_loss: 0.5081
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 4.1353e-05 - val_accuracy: 0.9792 - val_loss: 0.5081
# Epoch 6/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 3.1263e-05 - val_accuracy: 0.9792 - val_loss: 0.5172
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 3.1263e-05 - val_accuracy: 0.9792 - val_loss: 0.5172
# Epoch 7/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.4667e-05 - val_accuracy: 0.9792 - val_loss: 0.5227
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.4667e-05 - val_accuracy: 0.9792 - val_loss: 0.5227
# Epoch 8/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 8.3985e-06 - val_accuracy: 0.9792 - val_loss: 0.5261
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 8.3985e-06 - val_accuracy: 0.9792 - val_loss: 0.5261
# Epoch 9/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 5.4989e-06 - val_accuracy: 0.9792 - val_loss: 0.5282
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 5.4989e-06 - val_accuracy: 0.9792 - val_loss: 0.5282
# Epoch 10/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 3.9251e-06 - val_accuracy: 0.9792 - val_loss: 0.5295
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 3.9251e-06 - val_accuracy: 0.9792 - val_loss: 0.5295
# Epoch 11/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 3.1215e-06 - val_accuracy: 0.9792 - val_loss: 0.5302
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 3.1215e-06 - val_accuracy: 0.9792 - val_loss: 0.5302
# Epoch 12/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 2.7447e-06 - val_accuracy: 0.9792 - val_loss: 0.5306
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 2.7447e-06 - val_accuracy: 0.9792 - val_loss: 0.5306
# Epoch 13/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 2.4460e-06 - val_accuracy: 0.9792 - val_loss: 0.5308
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 2.4460e-06 - val_accuracy: 0.9792 - val_loss: 0.5308
# Epoch 14/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 2.2144e-06 - val_accuracy: 0.9792 - val_loss: 0.5309
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 2.2144e-06 - val_accuracy: 0.9792 - val_loss: 0.5309
# Epoch 15/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 2.0610e-06 - val_accuracy: 0.9792 - val_loss: 0.5310
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 2.0610e-06 - val_accuracy: 0.9792 - val_loss: 0.5310
# Epoch 16/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.8873e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 1.0000 - loss: 1.8873e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 17/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 1.7504e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 1.7504e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 18/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.6519e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.6519e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 19/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.5469e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 1.0000 - loss: 1.5469e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# Epoch 20/20
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 1.4640e-06 - val_accuracy: 0.9792 - val_loss: 0.5311
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 1.4640e-06 - val_accuracy: 0.9792 - val_loss: 0.5311

# %% [markdown]
# ## Langkah 10: Evaluasi Model
# Menguji performa model pada data testing.

# %%
# Evaluate the model on test data
test_loss, test_acc = model.evaluate(X_test_scaled, y_test)
print("Akurasi Test:", test_acc)
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9062 - loss: 0.9756
# Akurasi Test: 0.90625
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9062 - loss: 0.9756
# Akurasi Test: 0.90625

# %% [markdown]
# ## Langkah 11: Prediksi dan Laporan Klasifikasi serta Visualisasi
# Membuat prediksi pada data test dan menampilkan classification report serta confusion matrix.

# %%
# Generate classification report and confusion matrix
y_pred_prob = model.predict(X_test_scaled)
y_pred = (y_pred_prob > 0.5).astype(int)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        80
#            1       0.97      0.84      0.90        80
#
#     accuracy                           0.91       160
#    macro avg       0.91      0.91      0.91       160
# weighted avg       0.91      0.91      0.91       160
#
# [[78  2]
#  [13 67]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91        80
#            1       0.97      0.84      0.90        80
#
#     accuracy                           0.91       160
#    macro avg       0.91      0.91      0.91       160
# weighted avg       0.91      0.91      0.91       160
#
# [[78  2]
#  [13 67]]

# %%
# Visualize training history
plt.plot(history.history['accuracy'], label='Train Acc')
plt.plot(history.history['val_accuracy'], label='Val Acc')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# ## Langkah 12: Menyimpan Model dan Scaler
# Menyimpan model yang sudah dilatih ke dalam format .h5 dan scaler ke format .pkl untuk penggunaan deployment.

# %%
# Save the trained model
import pickle

# 1. Simpan Model
# Menggunakan format .h5
model.save('day_night_model.h5')
print("✅ Model berhasil disimpan sebagai: day_night_model.h5")

# 2. Simpan Scaler
with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
print("✅ Scaler berhasil disimpan sebagai: scaler.pkl")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Model berhasil disimpan sebagai: day_night_model.h5
# ✅ Scaler berhasil disimpan sebagai: scaler.pkl
